# %%
import os
import numpy as np
import coacd
import trimesh

input_file = r"/home/ltx/THU-AIR/AIR_winter/hand_asset/inspire_right_hand_model/meshes/right_little_2.STL"


mesh = trimesh.load(input_file, force="mesh")
mesh = coacd.Mesh(mesh.vertices, mesh.faces)
parts = coacd.run_coacd(mesh) # a list of convex hulls.
# Out:
# [2025-01-22 11:15:10.806] [CoACD] [info] threshold               0.05
# [2025-01-22 11:15:10.806] [CoACD] [info] max # convex hull       -1
# [2025-01-22 11:15:10.806] [CoACD] [info] preprocess mode         auto
# [2025-01-22 11:15:10.806] [CoACD] [info] preprocess resolution   30
# [2025-01-22 11:15:10.806] [CoACD] [info] pca                     false
# [2025-01-22 11:15:10.806] [CoACD] [info] mcts max depth          3
# [2025-01-22 11:15:10.806] [CoACD] [info] mcts nodes              20
# [2025-01-22 11:15:10.806] [CoACD] [info] mcts iterations         150
# [2025-01-22 11:15:10.806] [CoACD] [info] merge                   true
# [2025-01-22 11:15:10.806] [CoACD] [info] decimate                false
# [2025-01-22 11:15:10.806] [CoACD] [info] max_ch_vertex           256
# [2025-01-22 11:15:10.806] [CoACD] [info] extrude                 false
# [2025-01-22 11:15:10.806] [CoACD] [info] extrude margin          0.01
# [2025-01-22 11:15:10.806] [CoACD] [info] approximate mode        ch
# [2025-01-22 11:15:10.806] [CoACD] [info] seed                    0
# [2025-01-22 11:15:10.807] [CoACD] [info]  - Manifold Check
# [2025-01-22 11:15:10.820] [CoACD] [info] [1/3] Edge check finish
# [2025-01-22 11:15:10.840] [CoACD] [info] [2/3] Self-intersection check finish
# [2025-01-22 11:15:10.840] [CoACD] [info] [3/3] Triangle orientation check finish. Reversed: false
# [2025-01-22 11:15:10.840] [CoACD] [info] Manifold Check Time: 0.0341s
# [2025-01-22 11:15:10.843] [CoACD] [info] Mesh Manifoldness: true
# [2025-01-22 11:15:10.844] [CoACD] [info] # Points: 7516
# [2025-01-22 11:15:10.844] [CoACD] [info] # Triangles: 15044
# [2025-01-22 11:15:10.844] [CoACD] [info]  - Decomposition (MCTS)
# [2025-01-22 11:15:10.844] [CoACD] [info] iter 0 ---- waiting pool: 1
# [2025-01-22 11:15:10.852] [CoACD] [info] Processing [0.0%]
# [2025-01-22 11:15:13.585] [CoACD] [info] Processing [100.0%]
# [2025-01-22 11:15:13.585] [CoACD] [info] iter 1 ---- waiting pool: 2
# [2025-01-22 11:15:13.590] [CoACD] [info] Processing [0.0%]
# [2025-01-22 11:15:13.590] [CoACD] [info] Processing [50.0%]
# [2025-01-22 11:15:14.419] [CoACD] [info] Processing [100.0%]
# [2025-01-22 11:15:14.419] [CoACD] [info] iter 2 ---- waiting pool: 2
# [2025-01-22 11:15:14.419] [CoACD] [info] Processing [0.0%]
# [2025-01-22 11:15:14.419] [CoACD] [info] Processing [50.0%]
# [2025-01-22 11:15:15.203] [CoACD] [info] Processing [100.0%]
# [2025-01-22 11:15:15.203] [CoACD] [info] iter 3 ---- waiting pool: 4
# [2025-01-22 11:15:15.203] [CoACD] [info] Processing [0.0%]
# [2025-01-22 11:15:15.203] [CoACD] [info] Processing [25.0%]
# [2025-01-22 11:15:15.204] [CoACD] [info] Processing [75.0%]
# [2025-01-22 11:15:15.204] [CoACD] [info] Processing [50.0%]
# [2025-01-22 11:15:15.876] [CoACD] [info] Processing [100.0%]
# [2025-01-22 11:15:15.876] [CoACD] [info] iter 4 ---- waiting pool: 6
# [2025-01-22 11:15:15.876] [CoACD] [info] Processing [0.0%]
# [2025-01-22 11:15:15.876] [CoACD] [info] Processing [50.0%]
# [2025-01-22 11:15:15.876] [CoACD] [info] Processing [33.3%]
# [2025-01-22 11:15:15.876] [CoACD] [info] Processing [66.7%]
# [2025-01-22 11:15:15.876] [CoACD] [info] Processing [16.7%]
# [2025-01-22 11:15:15.877] [CoACD] [info] Processing [83.3%]
# [2025-01-22 11:15:16.526] [CoACD] [info] Processing [100.0%]
# [2025-01-22 11:15:16.526] [CoACD] [info] iter 5 ---- waiting pool: 12
# [2025-01-22 11:15:16.529] [CoACD] [info] Processing [0.0%]
# [2025-01-22 11:15:16.529] [CoACD] [info] Processing [33.3%]
# [2025-01-22 11:15:16.529] [CoACD] [info] Processing [16.7%]
# [2025-01-22 11:15:16.529] [CoACD] [info] Processing [66.7%]
# [2025-01-22 11:15:16.529] [CoACD] [info] Processing [50.0%]
# [2025-01-22 11:15:16.529] [CoACD] [info] Processing [83.3%]
# [2025-01-22 11:15:17.180] [CoACD] [info] Processing [100.0%]
# [2025-01-22 11:15:17.181] [CoACD] [info] iter 6 ---- waiting pool: 20
# [2025-01-22 11:15:17.184] [CoACD] [info] Processing [0.0%]
# [2025-01-22 11:15:17.184] [CoACD] [info] Processing [15.0%]
# [2025-01-22 11:15:17.184] [CoACD] [info] Processing [30.0%]
# [2025-01-22 11:15:17.184] [CoACD] [info] Processing [45.0%]
# [2025-01-22 11:15:17.185] [CoACD] [info] Processing [75.0%]
# [2025-01-22 11:15:17.188] [CoACD] [info] Processing [90.0%]
# [2025-01-22 11:15:17.188] [CoACD] [info] Processing [60.0%]
# [2025-01-22 11:15:17.805] [CoACD] [info] Processing [100.0%]
# [2025-01-22 11:15:17.805] [CoACD] [info] iter 7 ---- waiting pool: 10
# [2025-01-22 11:15:17.807] [CoACD] [info] Processing [0.0%]
# [2025-01-22 11:15:17.807] [CoACD] [info] Processing [40.0%]
# [2025-01-22 11:15:17.807] [CoACD] [info] Processing [20.0%]
# [2025-01-22 11:15:17.807] [CoACD] [info] Processing [80.0%]
# [2025-01-22 11:15:17.807] [CoACD] [info] Processing [60.0%]
# [2025-01-22 11:15:18.144] [CoACD] [info] Processing [100.0%]
# [2025-01-22 11:15:18.144] [CoACD] [info] iter 8 ---- waiting pool: 6
# [2025-01-22 11:15:18.145] [CoACD] [info] Processing [0.0%]
# [2025-01-22 11:15:18.145] [CoACD] [info] Processing [16.7%]
# [2025-01-22 11:15:18.145] [CoACD] [info] Processing [33.3%]
# [2025-01-22 11:15:18.145] [CoACD] [info] Processing [50.0%]
# [2025-01-22 11:15:18.145] [CoACD] [info] Processing [83.3%]
# [2025-01-22 11:15:18.145] [CoACD] [info] Processing [66.7%]
# [2025-01-22 11:15:18.275] [CoACD] [info] Processing [100.0%]
# [2025-01-22 11:15:18.275] [CoACD] [info] iter 9 ---- waiting pool: 2
# [2025-01-22 11:15:18.275] [CoACD] [info] Processing [0.0%]
# [2025-01-22 11:15:18.275] [CoACD] [info] Processing [50.0%]
# [2025-01-22 11:15:18.409] [CoACD] [info] Processing [100.0%]
# [2025-01-22 11:15:18.410] [CoACD] [info] iter 10 ---- waiting pool: 2
# [2025-01-22 11:15:18.410] [CoACD] [info] Processing [0.0%]
# [2025-01-22 11:15:18.410] [CoACD] [info] Processing [50.0%]
# [2025-01-22 11:15:18.415] [CoACD] [info] Processing [100.0%]
# [2025-01-22 11:15:18.415] [CoACD] [info]  - Merge Convex Hulls
# [2025-01-22 11:15:18.774] [CoACD] [info] Compute Time: 7.930148407000161s
# [2025-01-22 11:15:18.774] [CoACD] [info] # Convex Hulls: 28

# %%
import shutil
output_dir = input_file.replace(".STL", "_convex_dec")
if os.path.exists(output_dir):
    shutil.rmtree(output_dir)
os.makedirs(output_dir)

#------ different for each part
rgba = "0.203922 0.203922 0.203922 1"

asset_name = input_file.split("/")[-1].replace(".STL", "")

asset_config = """
<mujocoinclude>
"""

geom_config = """
<mujocoinclude>
""".format(asset_name)

for i, part in enumerate(parts):
    output_file = os.path.join(output_dir, f"part_{i}.obj")
    part_mesh = trimesh.Trimesh(vertices=part[0], faces=part[1])
    part_mesh.export(output_file)
    asset_config += '  <mesh name="{}_part_{}" file="../meshes/{}_convex_dec/part_{}.obj" scale="1 1 1"/>\n'.format(asset_name, i, asset_name, i)
    geom_config += '  <geom type="mesh" rgba="{}" mesh="{}_part_{}"/>\n'.format(rgba, asset_name, i)
    # body_config += ' class="obj_collision"/>\n'




asset_config += "</mujocoinclude>\n"
print(asset_config)
with open(f"convex_dec_include/{asset_name}_asset_include.xml", "w") as fa:
    fa.write(asset_config)
print(f"{asset_name}_asset_include.xml 写入成功！")




geom_config += "</mujocoinclude>\n"
print(geom_config)
with open(f"convex_dec_include/{asset_name}_geom_include.xml", "w") as fg:
    fg.write(geom_config)
print(f"{asset_name}_geom_include.xml 写入成功！")
# Out:
# <mujocoinclude>
#   <mesh name="right_little_2_part_0" file="../meshes/right_little_2_convex_dec/part_0.obj" scale="1 1 1"/>
#   <mesh name="right_little_2_part_1" file="../meshes/right_little_2_convex_dec/part_1.obj" scale="1 1 1"/>
#   <mesh name="right_little_2_part_2" file="../meshes/right_little_2_convex_dec/part_2.obj" scale="1 1 1"/>
#   <mesh name="right_little_2_part_3" file="../meshes/right_little_2_convex_dec/part_3.obj" scale="1 1 1"/>
#   <mesh name="right_little_2_part_4" file="../meshes/right_little_2_convex_dec/part_4.obj" scale="1 1 1"/>
#   <mesh name="right_little_2_part_5" file="../meshes/right_little_2_convex_dec/part_5.obj" scale="1 1 1"/>
#   <mesh name="right_little_2_part_6" file="../meshes/right_little_2_convex_dec/part_6.obj" scale="1 1 1"/>
#   <mesh name="right_little_2_part_7" file="../meshes/right_little_2_convex_dec/part_7.obj" scale="1 1 1"/>
#   <mesh name="right_little_2_part_8" file="../meshes/right_little_2_convex_dec/part_8.obj" scale="1 1 1"/>
#   <mesh name="right_little_2_part_9" file="../meshes/right_little_2_convex_dec/part_9.obj" scale="1 1 1"/>
#   <mesh name="right_little_2_part_10" file="../meshes/right_little_2_convex_dec/part_10.obj" scale="1 1 1"/>
#   <mesh name="right_little_2_part_11" file="../meshes/right_little_2_convex_dec/part_11.obj" scale="1 1 1"/>
#   <mesh name="right_little_2_part_12" file="../meshes/right_little_2_convex_dec/part_12.obj" scale="1 1 1"/>
#   <mesh name="right_little_2_part_13" file="../meshes/right_little_2_convex_dec/part_13.obj" scale="1 1 1"/>
#   <mesh name="right_little_2_part_14" file="../meshes/right_little_2_convex_dec/part_14.obj" scale="1 1 1"/>
#   <mesh name="right_little_2_part_15" file="../meshes/right_little_2_convex_dec/part_15.obj" scale="1 1 1"/>
#   <mesh name="right_little_2_part_16" file="../meshes/right_little_2_convex_dec/part_16.obj" scale="1 1 1"/>
#   <mesh name="right_little_2_part_17" file="../meshes/right_little_2_convex_dec/part_17.obj" scale="1 1 1"/>
#   <mesh name="right_little_2_part_18" file="../meshes/right_little_2_convex_dec/part_18.obj" scale="1 1 1"/>
#   <mesh name="right_little_2_part_19" file="../meshes/right_little_2_convex_dec/part_19.obj" scale="1 1 1"/>
#   <mesh name="right_little_2_part_20" file="../meshes/right_little_2_convex_dec/part_20.obj" scale="1 1 1"/>
#   <mesh name="right_little_2_part_21" file="../meshes/right_little_2_convex_dec/part_21.obj" scale="1 1 1"/>
#   <mesh name="right_little_2_part_22" file="../meshes/right_little_2_convex_dec/part_22.obj" scale="1 1 1"/>
#   <mesh name="right_little_2_part_23" file="../meshes/right_little_2_convex_dec/part_23.obj" scale="1 1 1"/>
#   <mesh name="right_little_2_part_24" file="../meshes/right_little_2_convex_dec/part_24.obj" scale="1 1 1"/>
#   <mesh name="right_little_2_part_25" file="../meshes/right_little_2_convex_dec/part_25.obj" scale="1 1 1"/>
#   <mesh name="right_little_2_part_26" file="../meshes/right_little_2_convex_dec/part_26.obj" scale="1 1 1"/>
#   <mesh name="right_little_2_part_27" file="../meshes/right_little_2_convex_dec/part_27.obj" scale="1 1 1"/>
# </mujocoinclude>
#
# right_little_2_asset_include.xml 写入成功！
#
# <mujocoinclude>
#   <geom type="mesh" rgba="0.203922 0.203922 0.203922 1" mesh="right_little_2_part_0"/>
#   <geom type="mesh" rgba="0.203922 0.203922 0.203922 1" mesh="right_little_2_part_1"/>
#   <geom type="mesh" rgba="0.203922 0.203922 0.203922 1" mesh="right_little_2_part_2"/>
#   <geom type="mesh" rgba="0.203922 0.203922 0.203922 1" mesh="right_little_2_part_3"/>
#   <geom type="mesh" rgba="0.203922 0.203922 0.203922 1" mesh="right_little_2_part_4"/>
#   <geom type="mesh" rgba="0.203922 0.203922 0.203922 1" mesh="right_little_2_part_5"/>
#   <geom type="mesh" rgba="0.203922 0.203922 0.203922 1" mesh="right_little_2_part_6"/>
#   <geom type="mesh" rgba="0.203922 0.203922 0.203922 1" mesh="right_little_2_part_7"/>
#   <geom type="mesh" rgba="0.203922 0.203922 0.203922 1" mesh="right_little_2_part_8"/>
#   <geom type="mesh" rgba="0.203922 0.203922 0.203922 1" mesh="right_little_2_part_9"/>
#   <geom type="mesh" rgba="0.203922 0.203922 0.203922 1" mesh="right_little_2_part_10"/>
#   <geom type="mesh" rgba="0.203922 0.203922 0.203922 1" mesh="right_little_2_part_11"/>
#   <geom type="mesh" rgba="0.203922 0.203922 0.203922 1" mesh="right_little_2_part_12"/>
#   <geom type="mesh" rgba="0.203922 0.203922 0.203922 1" mesh="right_little_2_part_13"/>
#   <geom type="mesh" rgba="0.203922 0.203922 0.203922 1" mesh="right_little_2_part_14"/>
#   <geom type="mesh" rgba="0.203922 0.203922 0.203922 1" mesh="right_little_2_part_15"/>
#   <geom type="mesh" rgba="0.203922 0.203922 0.203922 1" mesh="right_little_2_part_16"/>
#   <geom type="mesh" rgba="0.203922 0.203922 0.203922 1" mesh="right_little_2_part_17"/>
#   <geom type="mesh" rgba="0.203922 0.203922 0.203922 1" mesh="right_little_2_part_18"/>
#   <geom type="mesh" rgba="0.203922 0.203922 0.203922 1" mesh="right_little_2_part_19"/>
#   <geom type="mesh" rgba="0.203922 0.203922 0.203922 1" mesh="right_little_2_part_20"/>
#   <geom type="mesh" rgba="0.203922 0.203922 0.203922 1" mesh="right_little_2_part_21"/>
#   <geom type="mesh" rgba="0.203922 0.203922 0.203922 1" mesh="right_little_2_part_22"/>
#   <geom type="mesh" rgba="0.203922 0.203922 0.203922 1" mesh="right_little_2_part_23"/>
#   <geom type="mesh" rgba="0.203922 0.203922 0.203922 1" mesh="right_little_2_part_24"/>
#   <geom type="mesh" rgba="0.203922 0.203922 0.203922 1" mesh="right_little_2_part_25"/>
#   <geom type="mesh" rgba="0.203922 0.203922 0.203922 1" mesh="right_little_2_part_26"/>
#   <geom type="mesh" rgba="0.203922 0.203922 0.203922 1" mesh="right_little_2_part_27"/>
# </mujocoinclude>
#
# right_little_2_geom_include.xml 写入成功！
